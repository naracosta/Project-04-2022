# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sweetviz as sv

# %%
df = pd.read_csv(r"C:\Users\aluga.com\Documents\meus_projetos\Project-DataScience\analytics\dataframes\heart_2020_cleaned.csv")

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df['HeartDisease'] = df['HeartDisease'].replace(['Yes','No'],[1,0])
df['Smoking'] = df['Smoking'].replace(['Yes','No'],['1','0'])
df['AlcoholDrinking'] = df['AlcoholDrinking'].replace(['Yes','No'],['1','0'])
df['Stroke'] = df['Stroke'].replace(['Yes','No'],['1','0'])
df['Sex'] = df['Sex'].replace(['Female','Male'],['1','0'])
df['Diabetic'] = df['Diabetic'].replace(['Yes','No', 'No, borderline diabetes', 'Yes (during pregnancy)'],['1','0','0','0'])
df['Asthma'] = df['Asthma'].replace(['Yes','No'],['1','0'])
df['KidneyDisease'] = df['KidneyDisease'].replace(['Yes','No'],['1','0'])
df['SkinCancer'] = df['SkinCancer'].replace(['Yes','No'],['1','0'])
df['DiffWalking'] = df['DiffWalking'].replace(['Yes','No'],['1','0'])
df['PhysicalActivity'] = df['PhysicalActivity'].replace(['Yes','No'],['1','0'])

# %%
df.head()
# Out:
#    HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0             0  16.60       1               0      0             3.0
# 1             0  20.34       0               0      1             0.0
# 2             0  26.58       1               0      0            20.0
# 3             0  24.21       0               0      0             0.0
# 4             0  23.71       0               0      0            28.0
#
#    MentalHealth DiffWalking Sex  AgeCategory   Race Diabetic PhysicalActivity  \
# 0          30.0           0   1        55-59  White        1                1
# 1           0.0           0   1  80 or older  White        0                1
# 2          30.0           0   0        65-69  White        1                1
# 3           0.0           0   1        75-79  White        0                0
# 4           0.0           1   1        40-44  White        0                1
#
#    GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %%
df_columns = ['HeartDisease'] 
df_columns_select = df.filter(items=df_columns)
df_columns_select.count()
# Out:
# HeartDisease    319795
# dtype: int64

# %%
x = df_columns_select.count()
y = df_columns_select.sum()
z = round(y/x, 3)
print('A porcentagem de pessoas que tem doença no coração do total é: ', z)
#print(x)
#print(y)
# Out:
# A porcentagem de pessoas que tem doença no coração do total é:  HeartDisease    0.086
# SleepTime       7.097
# dtype: float64

# %%
df_columns = ['HeartDisease', 'SleepTime'] 
df_columns_select = df.filter(items=df_columns)

# %%
#df_columns_select.loc[(df['HeartDisease'] == 1) & (df_columns_select['SleepTime'] >= 8), 'HeartDisease_SleepTime'] = 1
#df_columns_select['HeartDisease_SleepTime'] = df_columns_select['HeartDisease_SleepTime'].replace([''],[0])
#df_columns_select[(df_columns_select.HeartDisease == 1) & (df_columns_select.SleepTime >= 8) & (df_columns_select.SleepTime <= 6)]
#df_columns_select.head()
#df_columns_select['SleepTime'].between(6,8).astype(int)

#df_columns_select[(df_columns_select.HeartDisease == 1) & (df_columns_select.SleepTime == 6)].sum()
#df_columns_select[(df_columns_select.HeartDisease == 1) & (df_columns_select.SleepTime.between(8,15))].sum()
df_columns_select[(df_columns_select.HeartDisease == 1) & (df_columns_select.SleepTime.between(6,8))].sum()
# Out:
# HeartDisease     20110.0
# SleepTime       143701.0
# dtype: float64

# %%
# porcentagem total de pessoas quem tem doença no coração: 8,6%
q = (6325/y)*z # pessoas que dormem 6 horas por dia tem 1,9% de chance de ter ataque do coração
u = (6325/y)*z # pessoas que dormem 7 horas por dia tem 1,9% de chance de terem ataque no coração
w = (14683/y)*z # pessoas que dormem entre 7 a 8 horas tem 4,61% de chances de ter um ataque no coração no total
x = (20110/y)*z # pessoas que dormem de 6 a 8 horas tem 6,41% de chances de ter um ataque no coração no total
i = ((9172 + 11793)/y)*z # pessoas que dorme menos de 6 horas e mais de 8 horas tem 6,5% de chance de ter ataque no coração 
                            # 75,5% de todos os casos que tiveram ataques no coração

# %%
my_report = sv.analyze(df)
my_report.show_html()
# Out:
#                                              |                                                                …
# C:\Users\aluga.com\Documents\meus_projetos\.venv\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# C:\Users\aluga.com\Documents\meus_projetos\.venv\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# C:\Users\aluga.com\Documents\meus_projetos\.venv\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
